# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from census import Census
import gmaps
import csv

# Census & gmaps API Keys
from config import (api_key, gkey)
c = Census(api_key, year=2020)

# Configure gmaps
gmaps.configure(api_key=gkey)

# State FIPS codes
# This is where you're going to import the FIPS codes from States.csv
states_df = pd.read_csv('resources/States.csv')

# %%
#c_variablesLink = "http://api.census.gov/data/2020/acs/acs5/variables.json"
#variablesData = requests.get(c_variablesLink).json()
#variables_pd = pd.DataFrame(variablesData)
# print(variables_pd)
#variables_pd.to_csv('variabledata.csv')

# %%
census_data_pbr = c.acs5.get(("B02001_002E","B02001_003E","B02001_004E","B02001_005E","B02001_006E","B02001_007E",
                          "B02001_008E","B02001_009E","B02001_010E","B01003_001E"), {'for': 'state:*'})

# Convert to DataFrame
census_pd_pbr = pd.DataFrame(census_data_pbr)
# census_pd_pbr['populationTotal'] = census_pd_pbr["B01003_001E"]
# = census_pd_pbr.sum(axis=1, numeric_only=True)
# Column Reordering
census_pd_pbr = census_pd_pbr.rename(columns={"B02001_002E":"White alone",
                                      "B02001_003E":"Black or African American alone",
                                      "B02001_004E":"American Indian and Alaska Native alone",
                                      "B02001_005E":"Asian alone",
                                      "B02001_006E":"Native Hawaiian and Other Pacific Islander alone",
                                      "B02001_007E":"Some other race alone",
                                      "B02001_008E":"Two or more races",
                                      "B02001_009E":"Two races including Some other race",
                                      "B02001_010E":"Two races excluding Some other race, and three or more races",
                                      "state":"State",
                                      "B01003_001E": "Total Population"})

census_pd_pbr = census_pd_pbr[["State", "Total Population","White alone","Black or African American alone","American Indian and Alaska Native alone","Asian alone",
                       "Native Hawaiian and Other Pacific Islander alone","Some other race alone","Two or more races",
                       "Two races including Some other race","Two races excluding Some other race, and three or more races"]]

# %%
# census_pd_pbr.sum(axis=1, numeric_only=True)

# %%
census_pd_pbr.head()
# Out:
#   State  Total Population  White alone  Black or African American alone  \
# 0    42        12794885.0   10155004.0                        1419582.0
# 1    06        39346023.0   22053721.0                        2250962.0
# 2    54         1807426.0    1672255.0                          64285.0
# 3    49         3151239.0    2682881.0                          38059.0
# 4    36        19514849.0   12160045.0                        3002401.0
#
#    American Indian and Alaska Native alone  Asian alone  \
# 0                                  20798.0     449320.0
# 1                                 311629.0    5834312.0
# 2                                   3146.0      14228.0
# 3                                  33222.0      73190.0
# 4                                  76535.0    1674216.0
#
#    Native Hawaiian and Other Pacific Islander alone  Some other race alone  \
# 0                                            4268.0               312888.0
# ...

# %%
# print(states_df.loc("code",0))

# print (states_df.query('Code" == "0"')["Abbreviation"])
# states_df.query('Code == 1')['Abbreviation']

# states_df

# %%
census_data_pbrZip = c.acs5.get(("B02001_002E","B02001_003E","B02001_004E","B02001_005E","B02001_006E","B02001_007E",
                          "B02001_008E","B02001_009E","B02001_010E"), {'for': 'zip code tabulation area:*'})
census_pd_pbrZip = pd.DataFrame(census_data_pbrZip)
census_pd_pbrZip['rowTotal'] = census_pd_pbrZip.sum(axis=1, numeric_only= True)

census_pd_pbrZip = census_pd_pbrZip.rename(columns={
                                      "B02001_002E":"White alone",
                                      "B02001_003E":"Black or African American alone",
                                      "B02001_004E":"American Indian and Alaska Native alone",
                                      "B02001_005E":"Asian alone",
                                      "B02001_006E":"Native Hawaiian and Other Pacific Islander alone",
                                      "B02001_007E":"Some other race alone",
                                      "B02001_008E":"Two or more races",
                                      "B02001_009E":"Two races including Some other race",
                                      "B02001_010E":"Two races excluding Some other race, and three or more races",
                                      "zip code tabulation area":"Zip Code",
                                      "rowTotal": "Total Responses"
                                      })

census_pd_pbrZip = census_pd_pbrZip[["Zip Code","Total Responses","White alone","Black or African American alone","American Indian and Alaska Native alone","Asian alone",
                       "Native Hawaiian and Other Pacific Islander alone","Some other race alone","Two or more races",
                       "Two races including Some other race","Two races excluding Some other race, and three or more races"]]

# %%
census_pd_pbrZip.sample(25, random_state=100)
# Out:
#       Zip Code  Total Responses  White alone  Black or African American alone  \
# 25075    27502          44762.0      35151.0                           2759.0
# 17616    80440           2663.0       2428.0                             24.0
# 31910    99741            546.0        175.0                              0.0
# 26955    02635           2826.0       2652.0                            150.0
# 33013    60188          42921.0      26939.0                           2851.0
# 5336     03301          34512.0      29345.0                            969.0
# 24328    21702          44386.0      28382.0                           7406.0
# 27651    60455          16678.0      13275.0                            608.0
# 31409    46781            681.0        658.0                              0.0
# 30066    79012           2169.0       2143.0                              0.0
# 13706    18417           1031.0        989.0                              0.0
# ...

# %%
census_data_povGender_Zip = c.acs5.get(("B17003_004E","B17003_005E","B17003_006E","B17003_007E","B17003_009E","B17003_010E",
						  "B17003_011E","B17003_012E","B17003_015E","B17003_016E","B17003_017E","B17003_018E","B17003_020E",
						  "B17003_021E","B17003_022E","B17003_023E",), {"for": "zip code tabulation area:*"})
census_pd_povGender_Zip = pd.DataFrame(census_data_povGender_Zip)
census_pd_povGender_Zip['populationTotal'] = census_pd_povGender_Zip.sum(axis=1, numeric_only= True)
census_pd_povGender_Zip = census_pd_povGender_Zip.rename(columns={"B17003_004E":"Male Below Poverty: Less than high school graduate",
									"B17003_005E":"Male Below Poverty: High school graduate (includes equivalency)",
									"B17003_006E":"Male Below Poverty: Some college, associate's degree",
									"B17003_007E":"Male Below Poverty: Bachelor's degree or higher",
									"B17003_009E":"Female Below Poverty: Less than high school graduate",
									"B17003_010E":"Female Below Poverty: High school graduate (includes equivalency)",
									"B17003_011E":"Female Below Poverty: Some college, associate's degree",
									"B17003_012E":"Female Below Poverty: Bachelor's degree or higher",
									"B17003_015E":"Male Above Poverty: Less than high school graduate",
									"B17003_016E":"Male Above Poverty: High school graduate (includes equivalency)",
									"B17003_017E":"Male Above Poverty: Some college, associate's degree",
									"B17003_018E":"Male Above Poverty: Bachelor's degree or higher",
									"B17003_020E":"Female Above Poverty: Less than high school graduate",
									"B17003_021E":"Female Above Poverty: High school graduate (includes equivalency)",
									"B17003_022E":"Female Above Poverty: Some college, associate's degree",
									"B17003_023E":"Female Above Poverty: Bachelors degree or higher",
                                     "zip code tabulation area":"Zip Code",
                                     "populationTotal": "Total Responses" })

census_pd_povGender_Zip = census_pd_povGender_Zip[[
"Zip Code","Total Responses",
"Male Below Poverty: Less than high school graduate",
"Male Below Poverty: High school graduate (includes equivalency)",
"Male Below Poverty: Some college, associate's degree",
"Male Below Poverty: Bachelor's degree or higher",
"Female Below Poverty: Less than high school graduate",
"Female Below Poverty: High school graduate (includes equivalency)",
"Female Below Poverty: Some college, associate's degree",
"Female Below Poverty: Bachelor's degree or higher",
"Male Above Poverty: Less than high school graduate",
"Male Above Poverty: High school graduate (includes equivalency)",
"Male Above Poverty: Some college, associate's degree",
"Male Above Poverty: Bachelor's degree or higher",
"Female Above Poverty: Less than high school graduate",
"Female Above Poverty: High school graduate (includes equivalency)",
"Female Above Poverty: Some college, associate's degree",
"Female Above Poverty: Bachelors degree or higher"
]]


census_pd_povGender_Zip.sample(25, random_state=100)
# Out:
#       Zip Code  Total Population  \
# 25075    27502           28004.0
# 17616    80440            1918.0
# 31910    99741             323.0
# 26955    02635            2197.0
# 33013    60188           28762.0
# 5336     03301           22386.0
# 24328    21702           28366.0
# 27651    60455           10595.0
# 31409    46781             470.0
# 30066    79012            1297.0
# 13706    18417             740.0
# 3319     52327            2432.0
# 19880    38341            1685.0
# 3911     67260               0.0
# 29280    46126            3174.0
# 1678     08318            8642.0
# 13960    36401            5492.0
# 27454    13040            1729.0
# 25174    71266            1167.0
# 6910     38869             281.0
# 4700     70053           11741.0
# 2311     28018            3082.0
# 29048    77460              19.0
# 32253    64119           20980.0
# 6939     36312            4452.0
#
#        Male Below Poverty: Less than high school graduate  \
# ...

# %%
# census_pd_povGender_Zip.sample(25, random_state=100)

# %%
census_data_povRace = c.acs5.get(("B17001B_002E","B17001A_002E"), {"for": "zip code tabulation area:*"})
census_pd_povRace = pd.DataFrame(census_data_povRace)
census_pd_povRace = census_pd_povRace.rename(columns={"zip code tabulation area":"Zip Code",
                                                        "B17001B_002E":"Black respondants below poverty",
                                                       "B17001A_002E":"White respondants below poverty"})
census_pd_povRace.sample(25, random_state=100)
# Out:
#        Black respondants below poverty  White respondants below poverty  \
# 25075                            422.0                           1003.0
# 17616                              0.0                            280.0
# 31910                              0.0                             11.0
# 26955                              0.0                            169.0
# 33013                            401.0                           1377.0
# 5336                             142.0                           2454.0
# 24328                            829.0                           2515.0
# 27651                             37.0                           2240.0
# 31409                              0.0                             55.0
# 30066                              0.0                              0.0
# 13706                              0.0                             74.0
# 3319                               0.0                            233.0
# ...
